# %%
import requests

# %%
url="http://api.open-notify.org/iss-now.json"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# Status code for the response 
if response.status_code == 200:
    print("The endpoint is valid")
else:
    print("The end-point is ivalid")
# Out:
# The endpoint is valid

# %% [markdown]
# ### End-point of an API
# ![image.png](attachment:image.png)

# %%
response.raise_for_status
# Out:
# <bound method Response.raise_for_status of <Response [200]>>

# %%
data = response.json()
data
# Out:
# {'timestamp': 1611724672,
#  'iss_position': {'longitude': '-32.8156', 'latitude': '-34.8049'},
#  'message': 'success'}

# %%
iss_position = response.json()['iss_position']
print(iss_position)
# Out:
# {'longitude': '-32.8156', 'latitude': '-34.8049'}

# %%
longitude = response.json()['iss_position']['longitude']
print(longitude)
# Out:
# -32.8156

# %%
latitude = response.json()['iss_position']['latitude']
print(latitude)
# Out:
# -34.8049

# %% [markdown]
# ## Approach-2

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
type(response)
# Out:
# requests.models.Response

# %%
data = response.json()  # Converting the request into json format
type(data)  # This response is generally in the form of url
# Out:
# list

# %%
data[2]['user']   # Accessing via list(index manner)
# Out:
# {'login': 'meeseeksmachine',
#  'id': 39504233,
#  'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/meeseeksmachine',
#  'html_url': 'https://github.com/meeseeksmachine',
#  'followers_url': 'https://api.github.com/users/meeseeksmachine/followers',
#  'following_url': 'https://api.github.com/users/meeseeksmachine/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/meeseeksmachine/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/meeseeksmachine/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/meeseeksmachine/subscriptions',
#  'organizations_url': 'https://api.github.com/users/meeseeksmachine/orgs',
#  'repos_url': 'https://api.github.com/users/meeseeksmachine/repos',
#  'events_url': 'https://api.github.com/users/meeseeksmachine/events{/privacy}',
# ...

# %% [markdown]
# ## Taking the required fields and converting into data-frame`

# %%
import pandas as pd
df = pd.DataFrame(data,columns=['number','title','labels','state'])
df
# Out:
#     number                                              title                                             labels state
# 0    39430  BUG: read_json(orient='table') converts 'float...  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 1    39429  Backport PR #39406 on branch 1.2.x (DOC: link ...  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 2    39428  Backport PR #39376 on branch 1.2.x (REGR: writ...  [{'id': 1625435109, 'node_id': 'MDU6TGFiZWwxNj...  open
# 3    39427  REF: reuse can_hold_element for NumericIndex._...                                                 []  open
# 4    39426      BUG: sort_values create an unprintable object  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 5    39425            REF: de-duplicate MultiIndex validation                                                 []  open
# 6    39424  BUG: indexing with missing labels deprecation ...  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# ...
