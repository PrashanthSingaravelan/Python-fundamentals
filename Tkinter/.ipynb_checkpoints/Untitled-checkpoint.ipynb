# %%
import tkinter

# %%
window = tkinter.Tk()
window
# Out:
# <tkinter.Tk object .>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
window.mainloop() # Keeping  this at-last, and all the contents will be in-between creating the window and getting the window to run

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
window.title("My first GUI program")  # Gives the title to the window
# Out:
# ''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
window.mainloop()
